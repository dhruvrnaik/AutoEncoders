# %%
import torch
import numpy as np
import pandas as pd
import os
from skimage import io
from torchvision import datasets
import torchvision.transforms as transforms
from torch.utils.data import Dataset

# convert data to torch.FloatTensor
transform =transforms.Compose([transforms.ToPILImage(),transforms.CenterCrop(100),transforms.ToTensor()])

# %%
class LoadDataset(Dataset):
    def __init__(self, csv_file, root_dir):
        self.landmarks_frame = pd.read_csv(csv_file)
        self.root_dir = root_dir
        self.transform = transform

    def __len__(self):
        return len(self.landmarks_frame)

    def __getitem__(self, idx):
        img_name = os.path.join(self.root_dir,
                                self.landmarks_frame.iloc[idx, 0])
        image = io.imread(img_name)
       
        landmarks = self.landmarks_frame.iloc[idx, 1:].values
        y = np.asarray([float(landmarks[0]),float(landmarks[1]),float(landmarks[2]),float(landmarks[3])])
        if self.transform:
            image = self.transform(image)
#            print(idx,"   ",y)
            y = torch.from_numpy(y).type(torch.FloatTensor)
        return [image,y]
data = LoadDataset("autoencode_flipkart.csv","/media/dhruv/Games/flipkart_round3/training")

# %%
batch_size=28
num_workers = 0

trainloader = torch.utils.data.DataLoader(data,num_workers=num_workers,batch_size=batch_size)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
    
# obtain one batch of training images
dataiter = iter(trainloader)
images, labels = dataiter.next()
images = images.numpy()

# get one image from the batch
img = np.squeeze(images[0])
fig = plt.figure(figsize = (5,5)) 
ax = fig.add_subplot(111)
ax.imshow(img.transpose((1,2,0)))

# %%
import torch.nn as nn
import torch.nn.functional as F
class ConvAutoencoder(nn.Module):
    def __init__(self):
        super(ConvAutoencoder, self).__init__()
        ## encoder layers ##
        # conv layer (depth from 1 --> 16), 3x3 kernels
        self.conv1 = nn.Conv2d(3, 16, 3, padding=1)  
        # conv layer (depth from 16 --> 4), 3x3 kernels
        self.conv2 = nn.Conv2d(16, 4, 3, padding=1)
        # pooling layer to reduce x-y dims by two; kernel and stride of 2
        self.pool = nn.MaxPool2d(2, 2)
        
        ## decoder layers ##
        ## a kernel of 2 and a stride of 2 will increase the spatial dims by 2
        self.t_conv1 = nn.ConvTranspose2d(4, 16, 2, stride=2)
        self.t_conv2 = nn.ConvTranspose2d(16, 3, 2, stride=2)


    def forward(self, x):
        ## encode ##
        # add hidden layers with relu activation function
        # and maxpooling after
        x = F.relu(self.conv1(x))
        x = self.pool(x)
        # add second hidden layer
        x = F.relu(self.conv2(x))
        x = self.pool(x)  # compressed representation
        
        ## decode ##
        # add transpose conv layers, with relu activation function
        x = F.relu(self.t_conv1(x))
        # output layer (with sigmoid for scaling from 0 to 1)
        x = F.sigmoid(self.t_conv2(x))
                
        return x

# initialize the NN
model = ConvAutoencoder()
print(model)
# Out:
# ConvAutoencoder(
#   (conv1): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv2): Conv2d(16, 4, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (t_conv1): ConvTranspose2d(4, 16, kernel_size=(2, 2), stride=(2, 2))
#   (t_conv2): ConvTranspose2d(16, 3, kernel_size=(2, 2), stride=(2, 2))
# )

# %%
# specify loss function
criterion = nn.MSELoss()

# specify loss function
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')

# %%
# number of epochs to train the model
n_epochs = 50

model = model.to(device)
for epoch in range(1, n_epochs+1):
    # monitor training loss
    train_loss = 0.0
    
    ###################
    # train the model #
    ###################
    for data in train_loader:
        # _ stands in for labels, here
        # no need to flatten images
        images, _ = data
        images = images.to(device)
        # clear the gradients of all optimized variables
        optimizer.zero_grad()
        # forward pass: compute predicted outputs by passing inputs to the model
        outputs = model(images)
        # calculate the loss
        loss = criterion(outputs, images)
        # backward pass: compute gradient of the loss with respect to model parameters
        loss.backward()
        # perform a single optimization step (parameter update)
        optimizer.step()
        # update running training loss
        train_loss += loss.item()*images.size(0)
            
    # print avg training statistics 
    train_loss = train_loss/len(train_loader)
    print('Epoch: {} \tTraining Loss: {:.6f}'.format(
        epoch, 
        train_loss
        ))
# Out:
# Epoch: 1 	Training Loss: 0.178832
# Epoch: 2 	Training Loss: 0.178749
# Epoch: 3 	Training Loss: 0.178671
# Epoch: 4 	Training Loss: 0.178594
# Epoch: 5 	Training Loss: 0.178520
# Epoch: 6 	Training Loss: 0.178446
# Epoch: 7 	Training Loss: 0.178374
# Epoch: 8 	Training Loss: 0.178302
# Epoch: 9 	Training Loss: 0.178233
# Epoch: 10 	Training Loss: 0.178164
# Epoch: 11 	Training Loss: 0.178097
# Epoch: 12 	Training Loss: 0.178030
# Epoch: 13 	Training Loss: 0.177965
# Epoch: 14 	Training Loss: 0.177901
# Epoch: 15 	Training Loss: 0.177838
# Epoch: 16 	Training Loss: 0.177777
# Epoch: 17 	Training Loss: 0.177715
# Epoch: 18 	Training Loss: 0.177656
# Epoch: 19 	Training Loss: 0.177598
# Epoch: 20 	Training Loss: 0.177541
# Epoch: 21 	Training Loss: 0.177483
# Epoch: 22 	Training Loss: 0.177427
# Epoch: 23 	Training Loss: 0.177372
# Epoch: 24 	Training Loss: 0.177318
# Epoch: 25 	Training Loss: 0.177265
# Epoch: 26 	Training Loss: 0.177213
# Epoch: 27 	Training Loss: 0.177162
# Epoch: 28 	Training Loss: 0.177111
# Epoch: 29 	Training Loss: 0.177061
# Epoch: 30 	Training Loss: 0.177011
# Epoch: 31 	Training Loss: 0.176962
# Epoch: 32 	Training Loss: 0.176914
# Epoch: 33 	Training Loss: 0.176866
# Epoch: 34 	Training Loss: 0.176820
# Epoch: 35 	Training Loss: 0.176773
# Epoch: 36 	Training Loss: 0.176728
# Epoch: 37 	Training Loss: 0.176683
# Epoch: 38 	Training Loss: 0.176638
# Epoch: 39 	Training Loss: 0.176594
# Epoch: 40 	Training Loss: 0.176551
# Epoch: 41 	Training Loss: 0.176508
# Epoch: 42 	Training Loss: 0.176466
# Epoch: 43 	Training Loss: 0.176425
# Epoch: 44 	Training Loss: 0.176383
# Epoch: 45 	Training Loss: 0.176343
# Epoch: 46 	Training Loss: 0.176302
# Epoch: 47 	Training Loss: 0.176262
# Epoch: 48 	Training Loss: 0.176223
# Epoch: 49 	Training Loss: 0.176184
# Epoch: 50 	Training Loss: 0.176146

# %%
# obtain one batch of test images
dataiter = iter(trainloader)
images, labels = dataiter.next()


# get sample outputs
output = model(images.cuda())
# prep images for display
images = images.numpy()

# output is resized into a batch of images

# use detach when it's an output that requires_grad
output = output.cpu().detach().numpy()

# plot the first ten input images and then reconstructed images
plt.figure(figsize=(20,20))

plt.subplot(121)
plt.imshow(images[2].transpose((1,2,0)))

plt.subplot(122)
plt.imshow(output[2].transpose((1,2,0)))

# %%
class ConvAutoencoder(nn.Module):
    def __init__(self):
        super(ConvAutoencoder, self).__init__()
        ## encoder layers ##
        # conv layer (depth from 1 --> 16), 3x3 kernels
        self.conv1 = nn.Conv2d(3, 16, 3, padding=1)  
        # conv layer (depth from 16 --> 8), 3x3 kernels
        self.conv2 = nn.Conv2d(16, 4, 3, padding=1)
        # pooling layer to reduce x-y dims by two; kernel and stride of 2
        self.pool = nn.MaxPool2d(2, 2)
        
        ## decoder layers ##
        self.conv4 = nn.Conv2d(4, 16, 3, padding=1)
        self.conv5 = nn.Conv2d(16, 3, 3, padding=1)
        

    def forward(self, x):
        # add layer, with relu activation function
        # and maxpooling after
        x = F.relu(self.conv1(x))
        x = self.pool(x)
        # add hidden layer, with relu activation function
        x = F.relu(self.conv2(x))
        x = self.pool(x)  # compressed representation
        
        ## decoder 
        # upsample, followed by a conv layer, with relu activation function  
        # this function is called `interpolate` in some PyTorch versions
        x = F.upsample(x, scale_factor=2, mode='nearest')
        x = F.relu(self.conv4(x))
        # upsample again, output should have a sigmoid applied
        x = F.upsample(x, scale_factor=2, mode='nearest')
        x = F.sigmoid(self.conv5(x))
        
        return x

# initialize the NN
model2 = ConvAutoencoder()
print(model)
# Out:
# ConvAutoencoder(
#   (conv1): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv2): Conv2d(16, 4, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (t_conv1): ConvTranspose2d(4, 16, kernel_size=(2, 2), stride=(2, 2))
#   (t_conv2): ConvTranspose2d(16, 3, kernel_size=(2, 2), stride=(2, 2))
# )

# %%
# specify loss function
criterion = nn.MSELoss()

# specify loss function
optimizer = torch.optim.Adam(model2.parameters(), lr=0.001)

device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')

# %%
# number of epochs to train the model
n_epochs = 30

model2 = model2.to(device)
for epoch in range(1, n_epochs+1):
    # monitor training loss
    train_loss = 0.0
    
    ###################
    # train the model #
    ###################
    for data in train_loader:
        # _ stands in for labels, here
        # no need to flatten images
        images, _ = data
        images = images.to(device)
        # clear the gradients of all optimized variables
        optimizer.zero_grad()
        # forward pass: compute predicted outputs by passing inputs to the model
        outputs = model2(images)
        # calculate the loss
        loss = criterion(outputs, images)
        # backward pass: compute gradient of the loss with respect to model parameters
        loss.backward()
        # perform a single optimization step (parameter update)
        optimizer.step()
        # update running training loss
        train_loss += loss.item()*images.size(0)
            
    # print avg training statistics 
    train_loss = train_loss/len(train_loader)
    print('Epoch: {} \tTraining Loss: {:.6f}'.format(
        epoch, 
        train_loss
        ))
# Out:
# Epoch: 1 	Training Loss: 0.170060
# Epoch: 2 	Training Loss: 0.170060
# Epoch: 3 	Training Loss: 0.169301
# Epoch: 4 	Training Loss: 0.168196
# Epoch: 5 	Training Loss: 0.167711
# Epoch: 6 	Training Loss: 0.167273
# Epoch: 7 	Training Loss: 0.167255
# Epoch: 8 	Training Loss: 0.167853
# Epoch: 9 	Training Loss: 0.167269
# Epoch: 10 	Training Loss: 0.165784
# Epoch: 11 	Training Loss: 0.165339
# Epoch: 12 	Training Loss: 0.165016
# Epoch: 13 	Training Loss: 0.165349
# Epoch: 14 	Training Loss: 0.165172
# Epoch: 15 	Training Loss: 0.164062
# Epoch: 16 	Training Loss: 0.163509
# Epoch: 17 	Training Loss: 0.163385
# Epoch: 18 	Training Loss: 0.163716
# Epoch: 19 	Training Loss: 0.163304
# Epoch: 20 	Training Loss: 0.162342
# Epoch: 21 	Training Loss: 0.161923
# Epoch: 22 	Training Loss: 0.161964
# Epoch: 23 	Training Loss: 0.162152
# Epoch: 24 	Training Loss: 0.161511
# Epoch: 25 	Training Loss: 0.160791
# Epoch: 26 	Training Loss: 0.160574
# Epoch: 27 	Training Loss: 0.160737
# Epoch: 28 	Training Loss: 0.160547
# Epoch: 29 	Training Loss: 0.159834
# Epoch: 30 	Training Loss: 0.159433

# %%
# obtain one batch of test images
dataiter = iter(trainloader)
images, labels = dataiter.next()


# get sample outputs
output = model2(images.cuda())
# prep images for display
images = images.numpy()

# output is resized into a batch of images

# use detach when it's an output that requires_grad
output = output.cpu().detach().numpy()

# plot the first ten input images and then reconstructed images
plt.figure(figsize=(20,20))

plt.subplot(121)
plt.imshow(images[2].transpose((1,2,0)))

plt.subplot(122)
plt.imshow(output[2].transpose((1,2,0)))
