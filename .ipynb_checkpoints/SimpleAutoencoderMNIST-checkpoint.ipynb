# %%
import torch
import numpy as np
from torchvision import datasets
import torchvision.transforms as transforms

# %%
transform = transforms.Compose([transforms.ToTensor()])
train_data = datasets.MNIST(root="MNIST_data",download=True,train=True,transform=transform)
test_data = datasets.MNIST(root='MNIST_data',download=True,train=False,transform=transforms)

# %%
batch_size = 20
num_workers = 1

trainloader = torch.utils.data.DataLoader(train_data,batch_size=batch_size,num_workers=num_workers,shuffle=True)
testloader  = torch.utils.data.DataLoader(test_data, batch_size=batch_size,num_workers=num_workers)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
images,_ = next(iter(trainloader))
img=np.squeeze(images[0])
plt.figure(figsize=(15,15))
width,height = img.shape
thresh = img.max()/2.5
img = img.numpy()
for x in range(width):
    for y in range(height):
        val = round(img[x][y],2)
        plt.annotate(str(val),
                     color = 'white' if img[x][y]<thresh else 'black',
                     xy=(y,x),horizontalalignment='center',verticalalignment='center')
        
plt.imshow(img,cmap='gray')
# Out:
# Exception ignored in: <function _DataLoaderIter.__del__ at 0x7f3d31f872f0>
# Traceback (most recent call last):
#   File "/home/dhruv/anaconda3/envs/torch/lib/python3.7/site-packages/torch/utils/data/dataloader.py", line 399, in __del__
#     self._shutdown_workers()
#   File "/home/dhruv/anaconda3/envs/torch/lib/python3.7/site-packages/torch/utils/data/dataloader.py", line 378, in _shutdown_workers
#     self.worker_result_queue.get()
#   File "/home/dhruv/anaconda3/envs/torch/lib/python3.7/multiprocessing/queues.py", line 354, in get
#     return _ForkingPickler.loads(res)
#   File "/home/dhruv/anaconda3/envs/torch/lib/python3.7/site-packages/torch/multiprocessing/reductions.py", line 151, in rebuild_storage_fd
#     fd = df.detach()
#   File "/home/dhruv/anaconda3/envs/torch/lib/python3.7/multiprocessing/resource_sharer.py", line 57, in detach
#     with _resource_sharer.get_connection(self._id) as conn:
#   File "/home/dhruv/anaconda3/envs/torch/lib/python3.7/multiprocessing/resource_sharer.py", line 87, in get_connection
#     c = Client(address, authkey=process.current_process().authkey)
#   File "/home/dhruv/anaconda3/envs/torch/lib/python3.7/multiprocessing/connection.py", line 498, in Client
#     answer_challenge(c, authkey)
#   File "/home/dhruv/anaconda3/envs/torch/lib/python3.7/multiprocessing/connection.py", line 746, in answer_challenge
#     response = connection.recv_bytes(256)        # reject large message
#   File "/home/dhruv/anaconda3/envs/torch/lib/python3.7/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/home/dhruv/anaconda3/envs/torch/lib/python3.7/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/home/dhruv/anaconda3/envs/torch/lib/python3.7/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# ConnectionResetError: [Errno 104] Connection reset by peer

# %%
import torch.nn as nn

class Autoencoder(nn.Module):
    def __init__(self,enc_dim):
        super(Autoencoder,self).__init__()
        self.enc = nn.Linear(784,enc_dim)
        self.dec = nn.Linear(enc_dim,784)
        self.sig = nn.Sigmoid()
        
    def forward(self,x):
        x = x.view(x.size(0),-1)
        return self.sig(self.dec(self.enc(x)))

# %%
enc_dim=32
model = Autoencoder(enc_dim)

# %%
criterion = nn.MSELoss()

optimizer = torch.optim.Adam(model.parameters(),lr=0.001)

device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
device
# Out:
# device(type='cuda')

# %%
n_epochs = 20
model = model.to(device)
for epoch in range(1,n_epochs+1):
    train_loss=0.0
    for data,labels in  trainloader:
        
        data = data.view(data.size(0),-1)
        optimizer.zero_grad()
        data = data.to(device)
        output = model(data)
        loss = criterion(output,data)
        loss.backward()
        optimizer.step()
        
        train_loss += loss.item()   
    train_loss = train_loss/len(trainloader)
    print("Epoch :{} \t Training Loss: {} ".format(epoch,train_loss))
# Out:
# Epoch :1 	 Training Loss: 0.026877830039709807
# Epoch :2 	 Training Loss: 0.01140734885710602
# Epoch :3 	 Training Loss: 0.010489750947337598
# Epoch :4 	 Training Loss: 0.010272771747938047
# Epoch :5 	 Training Loss: 0.010163102296181023
# Epoch :6 	 Training Loss: 0.010088586723587166
# Epoch :7 	 Training Loss: 0.010039120350188266
# Epoch :8 	 Training Loss: 0.009999196921630453
# Epoch :9 	 Training Loss: 0.009966457162362833
# Epoch :10 	 Training Loss: 0.009939996684435754
# Epoch :11 	 Training Loss: 0.009914207504751782
# Epoch :12 	 Training Loss: 0.009904232320996622
# Epoch :13 	 Training Loss: 0.009886922499009718
# Epoch :14 	 Training Loss: 0.009873771551220368
# Epoch :15 	 Training Loss: 0.009863689890907457
# Epoch :16 	 Training Loss: 0.00985348631783078
# Epoch :17 	 Training Loss: 0.009842162866455813
# Epoch :18 	 Training Loss: 0.009834798215578
# Epoch :19 	 Training Loss: 0.009828114874195307
# Epoch :20 	 Training Loss: 0.00981672136997804

# %%
# obtain one batch of test images
dataiter = iter(trainloader)
images, labels = dataiter.next()

images_flatten = images.view(images.size(0), -1)
# get sample outputs
output = model(images_flatten.cuda())
# prep images for display
images = images.numpy()

# output is resized into a batch of images

output = output.view(batch_size,1,28,28)
# use detach when it's an output that requires_grad
output = output.cpu().detach().numpy()

# plot the first ten input images and then reconstructed images
fig, axes = plt.subplots(nrows=2, ncols=10, sharex=True, sharey=True, figsize=(10,2))

# input images on top row, reconstructions on bottom
for images, row in zip([images, output], axes):
    for img, ax in zip(images, row):
        ax.imshow(np.squeeze(img.transpose((1,2,0))),cmap='gray')
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)
# Out:
# Exception ignored in: <function _DataLoaderIter.__del__ at 0x7f3d31f872f0>
# Traceback (most recent call last):
#   File "/home/dhruv/anaconda3/envs/torch/lib/python3.7/site-packages/torch/utils/data/dataloader.py", line 399, in __del__
#     self._shutdown_workers()
#   File "/home/dhruv/anaconda3/envs/torch/lib/python3.7/site-packages/torch/utils/data/dataloader.py", line 378, in _shutdown_workers
#     self.worker_result_queue.get()
#   File "/home/dhruv/anaconda3/envs/torch/lib/python3.7/multiprocessing/queues.py", line 354, in get
#     return _ForkingPickler.loads(res)
#   File "/home/dhruv/anaconda3/envs/torch/lib/python3.7/site-packages/torch/multiprocessing/reductions.py", line 151, in rebuild_storage_fd
#     fd = df.detach()
#   File "/home/dhruv/anaconda3/envs/torch/lib/python3.7/multiprocessing/resource_sharer.py", line 57, in detach
#     with _resource_sharer.get_connection(self._id) as conn:
#   File "/home/dhruv/anaconda3/envs/torch/lib/python3.7/multiprocessing/resource_sharer.py", line 87, in get_connection
#     c = Client(address, authkey=process.current_process().authkey)
#   File "/home/dhruv/anaconda3/envs/torch/lib/python3.7/multiprocessing/connection.py", line 499, in Client
#     deliver_challenge(c, authkey)
#   File "/home/dhruv/anaconda3/envs/torch/lib/python3.7/multiprocessing/connection.py", line 729, in deliver_challenge
#     response = connection.recv_bytes(256)        # reject large message
#   File "/home/dhruv/anaconda3/envs/torch/lib/python3.7/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/home/dhruv/anaconda3/envs/torch/lib/python3.7/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/home/dhruv/anaconda3/envs/torch/lib/python3.7/multiprocessing/connection.py", line 383, in _recv
#     raise EOFError
# EOFError:

# %%
fin = np.zeros((4*28,4*28))
print(fin.shape)
for i in range(4):
    fin[i*28:i*28+28,0:28] = images[i]
    fin[i*28:i*28+28,28:56] = images[i+4]
    fin[i*28:i*28+28,56:84] = images[i+8]
    fin[i*28:i*28+28,84:112] = images[i+12]
# Out:
# (112, 112)

# %%
plt.figure(figsize=(25,25))
plt.imsave(arr=fin,fname='MNIST_gen_{}'.format(enc_dim),dpi=100,cmap='gray')
plt.imshow(fin,cmap='gray')
